# %%
import segmentation_models_3D as sm

encoder_weights = 'imagenet'
# Out:
# layers <module 'tensorflow.keras.layers' from 'f:\\fliar\\venv\\lib\\site-packages\\tensorflow\\keras\\layers\\__init__.py'>
# Segmentation Models: using `keras` framework.

# %%
model1 = sm.Unet('resnet18', input_shape=(64, 64, 64, 3), encoder_weights=encoder_weights)
print(model1.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# data (InputLayer)               [(None, 64, 64, 64,  0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 64, 64, 64, 3 9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding3d (ZeroPadding3D)  (None, 70, 70, 70, 3 0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv3D)                  (None, 32, 32, 32, 6 65856       zero_padding3d[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 32, 32, 32, 6 256         conv0[0][0]
# ...

# %%
model2 = sm.FPN('efficientnetb0', input_shape=(64, 64, 64, 3), encoder_weights=encoder_weights)
print(model2.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 64, 64, 64,  0
# __________________________________________________________________________________________________
# stem_conv (Conv3D)              (None, 32, 32, 32, 3 2592        input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 32, 32, 32, 3 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 32, 32, 32, 3 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv3D (None, 32, 32, 32, 3 864         stem_activation[0][0]
# ...

# %%
model3 = sm.Linknet('densenet121', input_shape=(64, 64, 64, 3), encoder_weights=encoder_weights)
print(model3.summary())
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 64, 64, 64,  0
# __________________________________________________________________________________________________
# zero_padding3d_18 (ZeroPadding3 (None, 70, 70, 70, 3 0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv3D)             (None, 32, 32, 32, 6 65856       zero_padding3d_18[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 32, 32, 32, 6 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 32, 32, 32, 6 0           conv1/bn[0][0]
# ...

# %%
model4 = sm.PSPNet('seresnet34', input_shape=(96, 96, 96, 3), encoder_weights=encoder_weights)
print(model4.summary())
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# data (InputLayer)               [(None, 96, 96, 96,  0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 96, 96, 96, 3 9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding3d_20 (ZeroPadding3 (None, 102, 102, 102 0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv3D)                  (None, 48, 48, 48, 6 65856       zero_padding3d_20[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 48, 48, 48, 6 256         conv0[0][0]
# ...
